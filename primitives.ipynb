# %% [markdown]
# # primitives

# %%
# %matplotlib notebook
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import utils

# %%
import importlib
importlib.reload(utils)
# Out:
# <module 'utils' from '/mnt/c/Users/onzuka/Documents/temp/IBMKM/3dfig/3d-figures/utils.py'>

# %% [markdown]
# ## 球

# %%
utils.render_sphere(radius=3)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### ワーク
#
# パラメータを変えながら実行して、大きな球を出力するにはどのようなパラメータにすればよいか言葉にしましょう

# %% [markdown]
# ## 円錐

# %%
utils.render_cone(radius=3, height=6)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### ワーク
#
# とがった円錐になるようパラメータを修正して、どのようなパラメータ設定にすればとがった円錐になるかを言葉にしましょう

# %% [markdown]
# ## 円柱

# %%
utils.render_cylinder(radius=3, height=20)
# Out:
# set heihgt between 0 and 10

# %% [markdown]
# ### ワーク
#
# 大きな円柱になるようパラメータを修正して、どのようなパラメータ設定にすれば大きな円柱になるかを言葉にしましょう

# %% [markdown]
# ## 直方体

# %%
utils.render_rectangular(length=1, width=2, height=3)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %% [markdown]
# ### ワーク
#
# 背が高く、幅が狭く、奥行きのある直方体になるようにパラメータを変えてみましょう
