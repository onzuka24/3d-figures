# %% [markdown]
# # 球体

# %%
# %matplotlib notebook
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import utils

# %%
import importlib
importlib.reload(utils)
# Out:
# <module 'utils' from '/mnt/c/Users/onzuka/Documents/temp/IBMKM/3dfig/3d-figures/utils.py'>

# %% [markdown]
# ## まずは実行してみる

# %%
utils.render_sphere(radius=10)
# Out:
# <img src="data:image/png;base64,..." width="600">
