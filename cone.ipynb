# %% [markdown]
# # 円錐

# %%
# %matplotlib notebook
from matplotlib import cm
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
import utils

max = 10

# %%
import importlib
importlib.reload(utils)
# Out:
# <module 'utils' from '/mnt/c/Users/onzuka/Documents/temp/IBMKM/3dfig/3d-figures/utils.py'>

# %% [markdown]
# ## パラメータ解説

# %% [markdown]
# ### 底面の半径
# radius
#
# ### 高さ
# height

# %%
fig = plt.figure(figsize=(6,6))
ax = fig.add_subplot(111, projection='3d')

theta = np.linspace(0, 2*np.pi, 100)
r = np.linspace(0, radius, 100)
t, R = np.meshgrid(theta, r)

X = R * np.cos(t)
Y = R * np.sin(t)
Z = -R * (height / radius) + height

ax.set_xlabel('x axis')
ax.set_ylabel('y axis')
ax.set_zlabel('z axis')
ax.set_xlim(-1 * max, max)
ax.set_ylim(-1 * max, max)
ax.set_zlim(0, max)
#ax.set_aspect('equal')
 
ax.plot_surface(X, Y, Z, alpha=0.8, cmap=cm.copper)
plt.show()
# Out:
# 各パラメータは{max}以下にしてください
# <img src="data:image/png;base64,..." width="600">

# %%
def render(radius=1, height=1):
    """
    describe cone on notebook
    arguments:
        radius: 底面の半径
        height: 高さ
    """
    if radius < 0 or radius > max:
        print(f"底面の半径は0から{max}の間の値にしてください")
        return
    if height < 0 or height > max:
        print(f"高さは0から{max}の間の値にしてください")
        return
    fig = plt.figure(figsize=(6,6))
    ax = fig.add_subplot(111, projection='3d')

    theta = np.linspace(0, 2*np.pi, 100)
    r = np.linspace(0, radius, 100)
    t, R = np.meshgrid(theta, r)

    X = R * np.cos(t)
    Y = R * np.sin(t)
    Z = -R * (height / radius) + height

    ax.set_xlabel('x axis')
    ax.set_ylabel('y axis')
    ax.set_zlabel('z axis')
    ax.set_xlim(-1 * max, max)
    ax.set_ylim(-1 * max, max)
    ax.set_zlim(0, max)
    #ax.set_aspect('equal')

    ax.plot_surface(X, Y, Z, alpha=0.8, cmap=cm.copper)
    plt.show()

# %%
render(radius=4, height=5)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
utils.render_cone(radius=3, height=8)
# Out:
# <img src="data:image/png;base64,..." width="600">
